# %% [markdown]
# ### Working through https://www.youtube.com/watch?v=AShHJdSIxkY, a lot of it follows standard documentation tbh

# %%
import pyaudio
# stream allows us to easily decode bit data
import struct
import numpy as np
import matplotlib.pyplot as plt

CHUNK = 1024 * 4 # number of samples per chunk
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100 # Hz!

# %%
# import numpy as np
# a = np.array([1, 2, 3])
# a.dtype
# a.astype('float32')

# %%
# %matplotlib tk

# %%
def rms(wf):
    """
    Calculates rms value of waveform wf
    """
    return np.sqrt(np.mean(wf ** 2))

# %%
# the main pyaudio object
p = pyaudio.PyAudio()
stream = p.open(
    format=FORMAT,
    channels=CHANNELS,
    rate=RATE,
    input=True,
    output=True,
    frames_per_buffer=CHUNK
)

fig, ax = plt.subplots()
x = np.arange(0, CHUNK, 1)
line, = ax.plot(x, x)
ax.set_ylim([-2**15,(2**15)-1])

rms_values = []

# code from https://bastibe.de/2013-05-30-speeding-up-matplotlib.html
while True:
    data = stream.read(CHUNK)
    npdata = np.frombuffer(data, dtype=np.int16)
    npdata = npdata.astype('float32')
    print(rms(npdata))
    print('------------------')
    line.set_ydata(npdata)
    fig.canvas.draw()
    fig.canvas.flush_events()


# plt.plot(npdata)
# Out:
# [  0.   0.  -1. ... -63. -64. -63.]
# [0.000e+00 0.000e+00 1.000e+00 ... 3.969e+03 4.096e+03 3.969e+03]
# ------------------
# [ -55.  -44.  -28. ... -143. -146. -146.]
# [ 3025.  1936.   784. ... 20449. 21316. 21316.]
# ------------------
# [-150. -153. -158. ...  -27.  -37.  -47.]
# [22500. 23409. 24964. ...   729.  1369.  2209.]
# ------------------
# [-55. -59. -58. ...  -5.   3.  15.]
# [3025. 3481. 3364. ...   25.    9.  225.]
# ------------------
# [ 24.  39.  47. ... -13. -13. -13.]
# [ 576. 1521. 2209. ...  169.  169.  169.]
# ------------------
# [-12. -12. -13. ...   3.   3.   3.]
# [144. 144. 169. ...   9.   9.   9.]
# ------------------
# [ 3.  4.  2. ... -3. -4. -1.]
# [ 9. 16.  4. ...  9. 16.  1.]
# ------------------
# [ 1.  0. -1. ... -1.  0.  0.]
# [1. 0. 1. ... 1. 0. 0.]
# ------------------
# [   1.   -3.   -4. ... -451. -466. -484.]
# [1.00000e+00 9.00000e+00 1.60000e+01 ... 2.03401e+05 2.17156e+05
#  2.34256e+05]
# ------------------
# [-500. -499. -486. ... -788. -814. -849.]
# [250000. 249001. 236196. ... 620944. 662596. 720801.]
# ------------------
# [-888. -926. -946. ... -469. -448. -421.]
# [788544. 857476. 894916. ... 219961. 200704. 177241.]
# ------------------
# [ -389.  -356.  -328. ... -1143. -1114. -1090.]
# [ 151321.  126736.  107584. ... 1306449. 1240996. 1188100.]
# ------------------
# [-1072. -1060. -1057. ...  -760.  -761.  -776.]
# [1149184. 1123600. 1117249. ...  577600.  579121.  602176.]
# ------------------
# [1.60801e+05 1.66464e+05 1.71396e+05 ... 1.44000e+02 1.69000e+02
#  1.44000e+02]
# ------------------
# [-9. -5. -4. ... 22. 18. 20.]
# [ 81.  25.  16. ... 484. 324. 400.]
# ------------------
# [ 22.  24.  26. ...  -3. -12. -20.]
# [484. 576. 676. ...   9. 144. 400.]
# ------------------
# [-29. -34. -34. ... -10. -10. -10.]
# [ 841. 1156. 1156. ...  100.  100.  100.]
# ------------------
# [ -7.  -5.  -7. ... -10. -10.  -7.]
# [ 49.  25.  49. ... 100. 100.  49.]
# ------------------
# [ -9.  -9. -10. ...  -3.  -4.  -7.]
# [ 81.  81. 100. ...   9.  16.  49.]
# ------------------
# [ -11.  -17.  -20. ... 1568. 1559. 1524.]
# [1.210000e+02 2.890000e+02 4.000000e+02 ... 2.458624e+06 2.430481e+06
#  2.322576e+06]
# ------------------
# [1460. 1371. 1266. ...   -3.    5.   27.]
# [2.131600e+06 1.879641e+06 1.602756e+06 ... 9.000000e+00 2.500000e+01
#  7.290000e+02]
# ------------------
# [ 61.  94. 112. ... 395. 259. 108.]
# [  3721.   8836.  12544. ... 156025.  67081.  11664.]
# ------------------
# [ -37. -168. -288. ...  570.  635.  686.]
# [  1369.  28224.  82944. ... 324900. 403225. 470596.]
# ------------------
# [710. 696. 647. ... 666. 717. 739.]
# [504100. 484416. 418609. ... 443556. 514089. 546121.]
# ------------------
# [  718.   655.   549. ... -1174. -1140. -1125.]
# [ 515524.  429025.  301401. ... 1378276. 1299600. 1265625.]
# ------------------
# [-1110. -1086. -1045. ...   315.   346.   372.]
# [1232100. 1179396. 1092025. ...   99225.  119716.  138384.]
# ------------------
# [ 393.  405.  394. ... -729. -713. -689.]
# [154449. 164025. 155236. ... 531441. 508369. 474721.]
# ------------------
# [-658. -627. -602. ...  154.  141.  129.]
# [432964. 393129. 362404. ...  23716.  19881.  16641.]
# ------------------
# [117. 106.  92. ...  46.  37.  27.]
# [13689. 11236.  8464. ...  2116.  1369.   729.]
# ------------------
# [19. 12.  6. ...  8. 11. 15.]
# [361. 144.  36. ...  64. 121. 225.]
# ------------------
# [ 16.  16.  15. ...   7.  -2. -12.]
# [256. 256. 225. ...  49.   4. 144.]
# ------------------
# [-19. -11.   6. ...  -3.  -4.  -3.]
# [361. 121.  36. ...   9.  16.   9.]
# ------------------
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-5-3775ca0eea45> in <module>
#      26     print('------------------')
#      27     line.set_ydata(npdata)
# ---> 28     fig.canvas.draw()
#      29     fig.canvas.flush_events()
#      30
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_tkagg.py in draw(self)
#       8     def draw(self):
#       9         super(FigureCanvasTkAgg, self).draw()
# ---> 10         _backend_tk.blit(self._tkphoto, self.renderer._renderer, (0, 1, 2, 3))
#      11         self._master.update_idletasks()
#      12
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\_backend_tk.py in blit(photoimage, aggimage, offsets, bbox)
#      73         bboxptr = (x1, x2, y1, y2)
#      74     else:
# ---> 75         photoimage.blank()
#      76         bboxptr = (0, width, 0, height)
#      77     _tkagg.blit(
#
# ~\Miniconda3\lib\tkinter\__init__.py in blank(self)
#    3546     def blank(self):
#    3547         """Display a transparent image."""
# -> 3548         self.tk.call(self.name, 'blank')
#    3549     def cget(self, option):
#    3550         """Return the value of OPTION."""
#
# TclError: invalid command name "pyimage10"
